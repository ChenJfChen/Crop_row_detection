# %%
from matplotlib import pyplot as plt
import cv2

# plt.gca().axes.get_xaxis().set_visible(False)
# plt.gca().axes.get_yaxis().set_visible(False)
# plt.rcParams["font.weight"] = "bold"
# plt.rcParams["axes.labelweight"] = "bold" 

figure, axes = plt.subplots(nrows=5, ncols=6,figsize=(25,15))

## Row 1 ##
axes[0,0].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\roi_gt\roi_gt_img005.png'))
axes[0,0].set_title("Ground Truth", fontsize = 20, fontweight='bold')
axes[0,0].text(15, 30, 'Row 1', style='italic', fontsize = 18,
        bbox={'facecolor': 'yellow', 'alpha': 0.5, 'pad': 5})

axes[0,1].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\hough_transform\hough_img005.png'))
axes[0,1].set_title("Hough Transform",fontsize = 20,fontweight='bold')

axes[0,2].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\sliding_window\slide_img005.png'))
axes[0,2].set_title("Sliding Window",fontsize = 20,fontweight='bold')

axes[0,3].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\TMGEM_roi\TMGEM_roi_img005.jpg'))
axes[0,3].set_title("TMGEM",fontsize = 20,fontweight='bold')

axes[0,4].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\cluster_least_sq\cluster_ls_img005.png'))
axes[0,4].set_title("Cluster - Least Sq.",fontsize = 20,fontweight='bold')

axes[0,5].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\cluster_ransac\cluster_ransac_img005.png'))
axes[0,5].set_title("CAROLIF",fontsize = 20,fontweight='bold')



##Row 2##
axes[1,0].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\roi_gt\roi_gt_img014.png'))
axes[1,0].text(15, 30, 'Row 2', style='italic', fontsize = 18,
        bbox={'facecolor': 'yellow', 'alpha': 0.5, 'pad': 5})
axes[1,1].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\hough_transform\hough_img014.png'))
axes[1,2].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\sliding_window\slide_img014.png'))
axes[1,3].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\TMGEM_roi\TMGEM_roi_img014.jpg'))
axes[1,4].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\cluster_least_sq\cluster_ls_img014.png'))
axes[1,5].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\cluster_ransac\cluster_ransac_img014.png'))

##Row 3##
axes[2,0].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\roi_gt\roi_gt_img136.png'))
axes[2,0].text(15, 30, 'Row 3', style='italic', fontsize = 18,
        bbox={'facecolor': 'yellow', 'alpha': 0.5, 'pad': 5})
axes[2,1].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\hough_transform\hough_img136.png'))
axes[2,2].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\sliding_window\slide_img136.png'))
axes[2,3].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\TMGEM_roi\TMGEM_roi_img136.jpg'))
axes[2,4].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\cluster_least_sq\cluster_ls_img136.png'))
axes[2,5].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\cluster_ransac\cluster_ransac_img136.png'))

##Row 4##
axes[3,0].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\roi_gt\roi_gt_img230.png'))
axes[3,0].text(15, 30, 'Row 4', style='italic', fontsize = 18,
        bbox={'facecolor': 'yellow', 'alpha': 0.5, 'pad': 5})
axes[3,1].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\hough_transform\hough_img230.png'))
axes[3,2].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\sliding_window\slide_img230.png'))
axes[3,3].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\TMGEM_roi\TMGEM_roi_img230.jpg'))
axes[3,4].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\cluster_least_sq\cluster_ls_img230.png'))
axes[3,5].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\cluster_ransac\cluster_ransac_img230.png'))

##Row 5##
axes[4,0].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\roi_gt\roi_gt_img021.png'))
axes[4,0].text(15, 30, 'Row 5', style='italic', fontsize = 18,
        bbox={'facecolor': 'yellow', 'alpha': 0.5, 'pad': 5})
axes[4,1].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\hough_transform\hough_img021.png'))
axes[4,2].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\sliding_window\slide_img021.png'))
axes[4,3].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\TMGEM_roi\TMGEM_roi_img021.jpg'))
axes[4,4].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\cluster_least_sq\cluster_ls_img021.png'))
axes[4,5].imshow(cv2.imread(r'C:\Users\khan1\jupyter_test_code\IoU_test\cluster_ransac\cluster_ransac_img021.png'))


plt.subplots_adjust(wspace=0, hspace=0)

for ax in axes.flat:
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.savefig(r"C:\Users\khan1\jupyter_test_code\IoU_test\image_result_compare.png", bbox_inches='tight')
#figure.tight_layout()
#plt.show()
